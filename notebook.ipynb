# %%
import requests
import json
from config import api_key

# %%
url = "https://www.carboninterface.com/api/v1/estimates"
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

# %%
def get_emissions_estimate_country(electricity_value, country):
    payload = {
        "type": "electricity",
        "electricity_unit": "kwh",
        "electricity_value": electricity_value,
        "country": country
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

# Example usage
countries = ["US","CA","AT","BE","BG","HR","CY","CZ","DK","EU-27","EU-27+1","EE","FI","FR","DE","GR","GU","IE","IT","LV","LT","LU","MT","NL","PL","PT","RO","SK","SI","ES","SE","GB"]

for country in countries:
    estimate = get_emissions_estimate_country(100, country)
    print(json.dumps(estimate, indent=4))
# Out:
# {
#     "data": {
#         "id": "6c26f3b0-4b9d-49dd-a30c-d17d6ecc7b02",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:35.223Z",
#             "carbon_g": 40326,
#             "carbon_lb": 88.9,
#             "carbon_kg": 40.33,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "1373e508-32c7-44bf-bf92-b5dc38d515f2",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:36.206Z",
#             "carbon_g": 13000,
#             "carbon_lb": 28.66,
#             "carbon_kg": 13.0,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "178c47b0-e2e2-4d0d-8fcb-c718fed0e312",
#         "type": "estimate",
#         "attributes": {
#             "country": "at",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:36.698Z",
#             "carbon_g": 8300,
#             "carbon_lb": 18.3,
#             "carbon_kg": 8.3,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "aec74331-bdfd-474f-9306-fed6cedba292",
#         "type": "estimate",
#         "attributes": {
#             "country": "be",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:37.123Z",
#             "carbon_g": 19200,
#             "carbon_lb": 42.33,
#             "carbon_kg": 19.2,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "aa990934-f264-42e4-a00e-b7ecbddda113",
#         "type": "estimate",
#         "attributes": {
#             "country": "bg",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:38.065Z",
#             "carbon_g": 35200,
#             "carbon_lb": 77.6,
#             "carbon_kg": 35.2,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "31227df5-c811-416d-8851-e39838c40920",
#         "type": "estimate",
#         "attributes": {
#             "country": "hr",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:38.473Z",
#             "carbon_g": 16400,
#             "carbon_lb": 36.16,
#             "carbon_kg": 16.4,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "61847f85-9ce4-4a0f-ab16-9c31ed702a67",
#         "type": "estimate",
#         "attributes": {
#             "country": "cy",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:38.876Z",
#             "carbon_g": 65300,
#             "carbon_lb": 143.96,
#             "carbon_kg": 65.3,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "a120cb1a-7eed-459f-aeb0-98668c3f1187",
#         "type": "estimate",
#         "attributes": {
#             "country": "cz",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:39.281Z",
#             "carbon_g": 38600,
#             "carbon_lb": 85.1,
#             "carbon_kg": 38.6,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "ba3c90d5-48f2-42c7-b349-f701a853dc78",
#         "type": "estimate",
#         "attributes": {
#             "country": "dk",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:39.700Z",
#             "carbon_g": 11600,
#             "carbon_lb": 25.57,
#             "carbon_kg": 11.6,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "2932ff77-3cbd-4515-ae68-b6f3052e1035",
#         "type": "estimate",
#         "attributes": {
#             "country": "eu-27",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:40.157Z",
#             "carbon_g": 22600,
#             "carbon_lb": 49.82,
#             "carbon_kg": 22.6,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "message": "Validation failed: Country provided is not supported."
# }
# {
#     "data": {
#         "id": "ab265f77-a585-4873-967e-6c472422cc9e",
#         "type": "estimate",
#         "attributes": {
#             "country": "ee",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:41.532Z",
#             "carbon_g": 66900,
#             "carbon_lb": 147.49,
#             "carbon_kg": 66.9,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "5adba70f-974d-46b2-99b3-45cc298021f3",
#         "type": "estimate",
#         "attributes": {
#             "country": "fi",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:41.966Z",
#             "carbon_g": 6700,
#             "carbon_lb": 14.77,
#             "carbon_kg": 6.7,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "c335dee6-f0f6-4552-b00b-927c52f35d56",
#         "type": "estimate",
#         "attributes": {
#             "country": "fr",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:42.851Z",
#             "carbon_g": 5500,
#             "carbon_lb": 12.13,
#             "carbon_kg": 5.5,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "b0997eb2-0d63-48f5-8b51-1f1cab6ee67e",
#         "type": "estimate",
#         "attributes": {
#             "country": "de",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:43.752Z",
#             "carbon_g": 30100,
#             "carbon_lb": 66.36,
#             "carbon_kg": 30.1,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "708b62cc-0787-4f14-8a85-c52563ebae19",
#         "type": "estimate",
#         "attributes": {
#             "country": "gr",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:44.677Z",
#             "carbon_g": 52200,
#             "carbon_lb": 115.08,
#             "carbon_kg": 52.2,
#             "carbon_mt": 0.05
#         }
#     }
# }
# {
#     "message": "Validation failed: Country provided is not supported."
# }
# {
#     "data": {
#         "id": "742aca1d-d262-4fa1-80fd-653cc8143acf",
#         "type": "estimate",
#         "attributes": {
#             "country": "ie",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:45.482Z",
#             "carbon_g": 29300,
#             "carbon_lb": 64.6,
#             "carbon_kg": 29.3,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "c8abffa6-ffa9-475a-a241-e3f837987c03",
#         "type": "estimate",
#         "attributes": {
#             "country": "it",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:45.907Z",
#             "carbon_g": 21200,
#             "carbon_lb": 46.74,
#             "carbon_kg": 21.2,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "a007829c-2c4f-42c6-a2ae-329a18dc6957",
#         "type": "estimate",
#         "attributes": {
#             "country": "lv",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:46.830Z",
#             "carbon_g": 9200,
#             "carbon_lb": 20.28,
#             "carbon_kg": 9.2,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "ba2ba120-e1f7-4a90-b56f-e0a8109ae6a9",
#         "type": "estimate",
#         "attributes": {
#             "country": "lt",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:47.206Z",
#             "carbon_g": 14600,
#             "carbon_lb": 32.19,
#             "carbon_kg": 14.6,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "0749bb19-1d60-43f9-bcef-d0ffd9ae9c95",
#         "type": "estimate",
#         "attributes": {
#             "country": "lu",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:47.586Z",
#             "carbon_g": 6900,
#             "carbon_lb": 15.21,
#             "carbon_kg": 6.9,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "3fd18aac-f99f-4f17-8a11-f014c2ca96f3",
#         "type": "estimate",
#         "attributes": {
#             "country": "mt",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:48.004Z",
#             "carbon_g": 35600,
#             "carbon_lb": 78.48,
#             "carbon_kg": 35.6,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "a15ab217-ca01-4943-b876-af10551bd58b",
#         "type": "estimate",
#         "attributes": {
#             "country": "nl",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:48.392Z",
#             "carbon_g": 31800,
#             "carbon_lb": 70.11,
#             "carbon_kg": 31.8,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "e65be49c-edce-4790-8cfc-9d73946eecc4",
#         "type": "estimate",
#         "attributes": {
#             "country": "pl",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:48.788Z",
#             "carbon_g": 72400,
#             "carbon_lb": 159.61,
#             "carbon_kg": 72.4,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "9beff21f-7711-4c04-bbdc-73f1407f2863",
#         "type": "estimate",
#         "attributes": {
#             "country": "pt",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:49.181Z",
#             "carbon_g": 20100,
#             "carbon_lb": 44.31,
#             "carbon_kg": 20.1,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "619b9c97-1b72-476d-b529-2596a1eb1cf9",
#         "type": "estimate",
#         "attributes": {
#             "country": "ro",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:49.586Z",
#             "carbon_g": 20800,
#             "carbon_lb": 45.86,
#             "carbon_kg": 20.8,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "56be88c9-2147-458f-ae62-7f8e58adcbe8",
#         "type": "estimate",
#         "attributes": {
#             "country": "sk",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:49.998Z",
#             "carbon_g": 9000,
#             "carbon_lb": 19.84,
#             "carbon_kg": 9.0,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "4a6b63fb-e8e5-497b-9e82-c758c208e198",
#         "type": "estimate",
#         "attributes": {
#             "country": "si",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:50.392Z",
#             "carbon_g": 21900,
#             "carbon_lb": 48.28,
#             "carbon_kg": 21.9,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "8f9ab375-46fe-401b-acda-46a05861f907",
#         "type": "estimate",
#         "attributes": {
#             "country": "es",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:50.794Z",
#             "carbon_g": 19000,
#             "carbon_lb": 41.89,
#             "carbon_kg": 19.0,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "7b1ee6f5-2e79-4302-b3ac-2bfb18fbd829",
#         "type": "estimate",
#         "attributes": {
#             "country": "se",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:51.186Z",
#             "carbon_g": 1300,
#             "carbon_lb": 2.87,
#             "carbon_kg": 1.3,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "53d9e6b3-288f-405e-a6d0-d10beb925f4d",
#         "type": "estimate",
#         "attributes": {
#             "country": "gb",
#             "state": null,
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:31:51.573Z",
#             "carbon_g": 20900,
#             "carbon_lb": 46.08,
#             "carbon_kg": 20.9,
#             "carbon_mt": 0.02
#         }
#     }
# }

# %%
def get_emissions_estimate_state(electricity_value, country, state):
    payload = {
        "type": "electricity",
        "electricity_unit": "kwh",
        "electricity_value": electricity_value,
        "country": country,
        "state": state
    }
    response = requests.post(url, headers=headers, json=payload)
    return response.json()

canada_states = ["AB","BC","MB","NB","NL","NT","NS","NU","ON","PE","QC","SK","YT"]
for state in canada_states:
    estimate = get_emissions_estimate_state(100, "ca", state)
    print(json.dumps(estimate, indent=4))
# Out:
# {
#     "data": {
#         "id": "409d5ccd-3e4e-4a34-876f-9aaf7e6c91d0",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "ab",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:33.306Z",
#             "carbon_g": 68000,
#             "carbon_lb": 149.91,
#             "carbon_kg": 68.0,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "ea30bdf8-db6b-4848-8d6f-5f7d29d40faa",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "bc",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:34.228Z",
#             "carbon_g": 1280,
#             "carbon_lb": 2.82,
#             "carbon_kg": 1.28,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "f84a112d-83af-4086-a12c-2208a95f69a2",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "mb",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:35.167Z",
#             "carbon_g": 140,
#             "carbon_lb": 0.31,
#             "carbon_kg": 0.14,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "52886faa-1aa2-470e-b748-05e346824ffd",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "nb",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:36.061Z",
#             "carbon_g": 30000,
#             "carbon_lb": 66.14,
#             "carbon_kg": 30.0,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "f9327bef-8fd6-4c15-98e8-fa5622fa990e",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "nl",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:36.970Z",
#             "carbon_g": 2700,
#             "carbon_lb": 5.95,
#             "carbon_kg": 2.7,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "73c00484-f3ee-415f-94c4-001ff0985b82",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "nt",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:37.879Z",
#             "carbon_g": 16000,
#             "carbon_lb": 35.27,
#             "carbon_kg": 16.0,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "d783c0d1-f79e-4f01-a3ac-8812db50bb34",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "ns",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:38.797Z",
#             "carbon_g": 76000,
#             "carbon_lb": 167.55,
#             "carbon_kg": 76.0,
#             "carbon_mt": 0.08
#         }
#     }
# }
# {
#     "data": {
#         "id": "85baa92c-f6c0-4af3-aada-45b1c789ec6a",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "nu",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:39.696Z",
#             "carbon_g": 89000,
#             "carbon_lb": 196.21,
#             "carbon_kg": 89.0,
#             "carbon_mt": 0.09
#         }
#     }
# }
# {
#     "data": {
#         "id": "7d6a1c1c-e2ef-44dc-84e6-2fa839d5d7d5",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "on",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:40.612Z",
#             "carbon_g": 3000,
#             "carbon_lb": 6.61,
#             "carbon_kg": 3.0,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "24f777ec-de1b-4cdc-8a5b-f5b66da4a62d",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "pe",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:40.998Z",
#             "carbon_g": 30000,
#             "carbon_lb": 66.14,
#             "carbon_kg": 30.0,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "70e6cac4-90b3-458c-9ff2-323b77b417ef",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "qc",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:41.908Z",
#             "carbon_g": 170,
#             "carbon_lb": 0.37,
#             "carbon_kg": 0.17,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "9091141c-8e5e-4653-94a2-425420de3845",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "sk",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:42.851Z",
#             "carbon_g": 71000,
#             "carbon_lb": 156.53,
#             "carbon_kg": 71.0,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "dbc9f0f2-0d0d-42a5-851b-3d3c8e6f8cf6",
#         "type": "estimate",
#         "attributes": {
#             "country": "ca",
#             "state": "yt",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:35:43.287Z",
#             "carbon_g": 7900,
#             "carbon_lb": 17.42,
#             "carbon_kg": 7.9,
#             "carbon_mt": 0.01
#         }
#     }
# }

# %%
us_states = [ "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC", "AS", "GU", "MP", "PR", "UM", "VI" ]
for state in us_states:
    estimate = get_emissions_estimate_state(100, "us", state)
    print(json.dumps(estimate, indent=4))
# Out:
# {
#     "data": {
#         "id": "6976b874-8678-4428-8193-843b1964f8cb",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "al",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:38:59.669Z",
#             "carbon_g": 35628,
#             "carbon_lb": 78.55,
#             "carbon_kg": 35.63,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "1aa35897-c587-4530-a872-3d758a2364c0",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ak",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:00.596Z",
#             "carbon_g": 44213,
#             "carbon_lb": 97.47,
#             "carbon_kg": 44.21,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "a75c6a95-2cff-4a9d-9f72-3fbfc8ec7bdc",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "az",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:00.987Z",
#             "carbon_g": 39605,
#             "carbon_lb": 87.32,
#             "carbon_kg": 39.61,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "081880d8-9487-46dc-9e0d-f45fe04d055e",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ar",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:01.392Z",
#             "carbon_g": 51151,
#             "carbon_lb": 112.77,
#             "carbon_kg": 51.15,
#             "carbon_mt": 0.05
#         }
#     }
# }
# {
#     "data": {
#         "id": "d75e7479-76fb-4c4d-b642-825dd3f99078",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ca",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:01.826Z",
#             "carbon_g": 17560,
#             "carbon_lb": 38.71,
#             "carbon_kg": 17.56,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "240f467f-234a-4f47-9e19-6685a5cff7ca",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "co",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:02.217Z",
#             "carbon_g": 60367,
#             "carbon_lb": 133.09,
#             "carbon_kg": 60.37,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "6d017044-7811-4696-866c-4b0c6b95bbce",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ct",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:02.605Z",
#             "carbon_g": 21650,
#             "carbon_lb": 47.73,
#             "carbon_kg": 21.65,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "e92037a3-c0dc-4812-bf49-95dadc49714a",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "de",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:02.996Z",
#             "carbon_g": 32267,
#             "carbon_lb": 71.14,
#             "carbon_kg": 32.27,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "4dbfcf1e-3a40-4f6c-a382-16b5debd4c5a",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "fl",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:03.377Z",
#             "carbon_g": 39786,
#             "carbon_lb": 87.71,
#             "carbon_kg": 39.79,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "dd949561-6641-460c-9080-a97f77937cb2",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ga",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:04.276Z",
#             "carbon_g": 39950,
#             "carbon_lb": 88.07,
#             "carbon_kg": 39.95,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "5c577a58-f187-4d4d-bf7f-a4df04fc61e3",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "hi",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:04.674Z",
#             "carbon_g": 70870,
#             "carbon_lb": 156.24,
#             "carbon_kg": 70.87,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "a4f9785c-dd60-4d1d-8ed4-77121708baff",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "id",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:05.070Z",
#             "carbon_g": 9587,
#             "carbon_lb": 21.14,
#             "carbon_kg": 9.59,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "3bfb7f6f-f319-4c11-9798-33d103207456",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "il",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:05.458Z",
#             "carbon_g": 32916,
#             "carbon_lb": 72.57,
#             "carbon_kg": 32.92,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "c01839f3-c4c6-4904-a449-8c66a0eeee19",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "in",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:05.863Z",
#             "carbon_g": 74113,
#             "carbon_lb": 163.39,
#             "carbon_kg": 74.11,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "d449aa24-1c63-44be-b443-763d9366e8e5",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ia",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:06.266Z",
#             "carbon_g": 39070,
#             "carbon_lb": 86.14,
#             "carbon_kg": 39.07,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "c6433b13-4d7e-475f-9b27-fb6ecafb7eb0",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ks",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:06.654Z",
#             "carbon_g": 40526,
#             "carbon_lb": 89.34,
#             "carbon_kg": 40.53,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "2bc83ab8-af45-4932-b704-908912697d9a",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ky",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:07.038Z",
#             "carbon_g": 80752,
#             "carbon_lb": 178.03,
#             "carbon_kg": 80.75,
#             "carbon_mt": 0.08
#         }
#     }
# }
# {
#     "data": {
#         "id": "7108608c-4dc2-4150-a912-8e51c8eddb66",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "la",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:07.427Z",
#             "carbon_g": 37473,
#             "carbon_lb": 82.62,
#             "carbon_kg": 37.47,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "c58f9e1a-8923-4682-aca8-ebf661bc769b",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "me",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:08.357Z",
#             "carbon_g": 9687,
#             "carbon_lb": 21.36,
#             "carbon_kg": 9.69,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "81f1cf9f-a278-4fea-b837-31f9a5f458d7",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "md",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:08.779Z",
#             "carbon_g": 33501,
#             "carbon_lb": 73.86,
#             "carbon_kg": 33.5,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "333741c9-6199-42cf-a3da-aef781a26e07",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ma",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:09.162Z",
#             "carbon_g": 35401,
#             "carbon_lb": 78.05,
#             "carbon_kg": 35.4,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "8494e3f4-abac-4109-842c-70bdf486cc12",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "mi",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:09.558Z",
#             "carbon_g": 45959,
#             "carbon_lb": 101.32,
#             "carbon_kg": 45.96,
#             "carbon_mt": 0.05
#         }
#     }
# }
# {
#     "data": {
#         "id": "90cdc372-2c1f-4095-8727-8ca6d48998b7",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "mn",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:09.942Z",
#             "carbon_g": 39950,
#             "carbon_lb": 88.07,
#             "carbon_kg": 39.95,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "847f0741-13c8-4d28-bcac-70c416025d55",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ms",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:10.336Z",
#             "carbon_g": 37977,
#             "carbon_lb": 83.73,
#             "carbon_kg": 37.98,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "aaf363e3-c008-43a8-acfb-e43828c639fd",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "mo",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:10.715Z",
#             "carbon_g": 72507,
#             "carbon_lb": 159.85,
#             "carbon_kg": 72.51,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "5f15c377-0fb0-4768-98f8-f2d59fc6fc17",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "mt",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:11.621Z",
#             "carbon_g": 57265,
#             "carbon_lb": 126.25,
#             "carbon_kg": 57.27,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "ade3429b-2ee5-4958-9f4c-7374cdf17e8e",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ne",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:12.015Z",
#             "carbon_g": 57396,
#             "carbon_lb": 126.54,
#             "carbon_kg": 57.4,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "a722d6d3-bcf9-45bc-834d-bdae2548b646",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nv",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:12.451Z",
#             "carbon_g": 33528,
#             "carbon_lb": 73.92,
#             "carbon_kg": 33.53,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "db4b2968-9b6d-42be-95c7-becb0401d477",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nh",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:12.840Z",
#             "carbon_g": 11619,
#             "carbon_lb": 25.62,
#             "carbon_kg": 11.62,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "405c8707-4f79-441d-9dba-54322876d058",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nj",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:14.338Z",
#             "carbon_g": 24725,
#             "carbon_lb": 54.51,
#             "carbon_kg": 24.73,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "f8271cec-fea2-435a-8c5b-d4bce5a964df",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nm",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:14.731Z",
#             "carbon_g": 60176,
#             "carbon_lb": 132.67,
#             "carbon_kg": 60.18,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "b83d3936-589d-4ffd-add5-12a094419fd9",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ny",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:15.149Z",
#             "carbon_g": 17151,
#             "carbon_lb": 37.81,
#             "carbon_kg": 17.15,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "ec458378-c08e-4db5-a2b9-42161722bd4e",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nc",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:15.549Z",
#             "carbon_g": 35351,
#             "carbon_lb": 77.94,
#             "carbon_kg": 35.35,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "d95a2697-f141-4283-b194-294a0997980b",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "nd",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:15.944Z",
#             "carbon_g": 65646,
#             "carbon_lb": 144.73,
#             "carbon_kg": 65.65,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "604ab7e9-d186-408c-99a9-7dbd29373322",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "oh",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:16.337Z",
#             "carbon_g": 56349,
#             "carbon_lb": 124.23,
#             "carbon_kg": 56.35,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "29b5689f-f894-4f27-8cf6-6b3877fb3f39",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ok",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:16.732Z",
#             "carbon_g": 33297,
#             "carbon_lb": 73.41,
#             "carbon_kg": 33.3,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "4d4a6ced-cf5b-463a-ae2b-96d4b568d016",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "or",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:17.118Z",
#             "carbon_g": 18054,
#             "carbon_lb": 39.8,
#             "carbon_kg": 18.05,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "3d76f4e2-3d2a-4d88-9544-835c08a40ab6",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "pa",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:17.516Z",
#             "carbon_g": 34412,
#             "carbon_lb": 75.87,
#             "carbon_kg": 34.41,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "6cce2924-213e-4250-8adb-42a8a6bc6b30",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ri",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:17.998Z",
#             "carbon_g": 38653,
#             "carbon_lb": 85.22,
#             "carbon_kg": 38.65,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "28fa0ca4-09ab-4f97-864a-ce169f5b7419",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "sc",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:18.410Z",
#             "carbon_g": 24417,
#             "carbon_lb": 53.83,
#             "carbon_kg": 24.42,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "2191caf6-22d3-4e51-aa6c-c1c91676c607",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "sd",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:18.838Z",
#             "carbon_g": 22317,
#             "carbon_lb": 49.2,
#             "carbon_kg": 22.32,
#             "carbon_mt": 0.02
#         }
#     }
# }
# {
#     "data": {
#         "id": "6ec854ec-f477-438c-a84d-1faf2dbb8ed1",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "tn",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:19.219Z",
#             "carbon_g": 31945,
#             "carbon_lb": 70.43,
#             "carbon_kg": 31.95,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "56e9b2b7-d32c-4db5-b75e-b467cfe3122d",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "tx",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:19.607Z",
#             "carbon_g": 41424,
#             "carbon_lb": 91.32,
#             "carbon_kg": 41.42,
#             "carbon_mt": 0.04
#         }
#     }
# }
# {
#     "data": {
#         "id": "8d191d21-64ce-47e0-b012-ab60c9fee0e5",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "ut",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:20.027Z",
#             "carbon_g": 72643,
#             "carbon_lb": 160.15,
#             "carbon_kg": 72.64,
#             "carbon_mt": 0.07
#         }
#     }
# }
# {
#     "data": {
#         "id": "68860afe-4a26-47c6-9424-c45f2c6e11bc",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "vt",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:20.456Z",
#             "carbon_g": 2326,
#             "carbon_lb": 5.13,
#             "carbon_kg": 2.33,
#             "carbon_mt": 0.0
#         }
#     }
# }
# {
#     "data": {
#         "id": "3895b714-a38e-4125-9a84-67db419c222f",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "va",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:20.873Z",
#             "carbon_g": 28834,
#             "carbon_lb": 63.57,
#             "carbon_kg": 28.83,
#             "carbon_mt": 0.03
#         }
#     }
# }
# {
#     "data": {
#         "id": "9e35ff56-375e-4b5d-8726-20ae32ada581",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "wa",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:21.288Z",
#             "carbon_g": 13564,
#             "carbon_lb": 29.9,
#             "carbon_kg": 13.56,
#             "carbon_mt": 0.01
#         }
#     }
# }
# {
#     "data": {
#         "id": "1d413cd8-24f1-4348-8bd7-d78a687921ce",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "wv",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:21.663Z",
#             "carbon_g": 88217,
#             "carbon_lb": 194.49,
#             "carbon_kg": 88.22,
#             "carbon_mt": 0.09
#         }
#     }
# }
# {
#     "data": {
#         "id": "25cc30a7-9e1f-40bc-b29f-86a301f32caa",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "wi",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:22.075Z",
#             "carbon_g": 55918,
#             "carbon_lb": 123.28,
#             "carbon_kg": 55.92,
#             "carbon_mt": 0.06
#         }
#     }
# }
# {
#     "data": {
#         "id": "14916b09-c6ac-4aef-a29f-bd1b2940830b",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "wy",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:22.479Z",
#             "carbon_g": 93832,
#             "carbon_lb": 206.86,
#             "carbon_kg": 93.83,
#             "carbon_mt": 0.09
#         }
#     }
# }
# {
#     "data": {
#         "id": "7f2e4675-563a-4501-ba9c-240497234ca9",
#         "type": "estimate",
#         "attributes": {
#             "country": "us",
#             "state": "dc",
#             "electricity_unit": "kwh",
#             "electricity_value": 100.0,
#             "estimated_at": "2024-09-02T11:39:22.879Z",
#             "carbon_g": 36176,
#             "carbon_lb": 79.76,
#             "carbon_kg": 36.18,
#             "carbon_mt": 0.04
#         }
#     }
# }
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\envs\dev\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\envs\dev\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\envs\dev\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[20], line 3
#       1 us_states = [ "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC", "AS", "GU", "MP", "PR", "UM", "VI" ]
#       2 for state in us_states:
# ----> 3     estimate = get_emissions_estimate_state(100, "us", state)
#       4     print(json.dumps(estimate, indent=4))
#
# Cell In[18], line 10, in get_emissions_estimate_state(electricity_value, country, state)
#       2 payload = {
#       3     "type": "electricity",
#       4     "electricity_unit": "kwh",
#    (...)
#       7     "state": state
#       8 }
#       9 response = requests.post(url, headers=headers, json=payload)
# ---> 10 return response.json()
#
# File ~\anaconda3\envs\dev\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
